# %%
from bs4 import BeautifulSoup
import requests
import csv
import os

# %%
positions = {
    'QB': 10,
    'RB': 20,
    'WR': 30,
    'TE': 40,
    'K': 80
}
weeks = range(1, 22)

# %%
def cbs(pos, week):
    url = 'https://www.fftoday.com/rankings/playerwkproj.php?Season=2017&GameWeek={week}&PosID={pos}&LeagueID=1'.format(pos=positions[pos], week=week)
    try:
        contents = requests.get(url).content
        soup = BeautifulSoup(contents, "html.parser")
        rows = soup.find_all('table')[9].find_all('tr')
        header = [td.text.rstrip().replace(u'\xa0', u'') for td in rows[2].find_all('td')]
        data = [[td.text.rstrip().replace(u'\xa0', u'') for td in row.find_all('td')] for row in rows[3:]]
    except IndexError:
        print("Failed: " + pos + " " + str(week))
        return
    filename = 'fftoday_{pos}_week{week}.csv'.format(pos=pos, week=week)
    with open(filename, 'w') as f:
        print('writing: ', filename)
        writer = csv.writer(f)
        try:
            writer.writerow(header)
            writer.writerows(data)
        except UnicodeEncodeError:
            print("Failed: " + pos + " " + str(week))
            print(header)
            print(data)
            return

# %%
os.chdir('fftoday')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-65-c2c813126354> in <module>()
# ----> 1 os.chdir('fftoday')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fftoday'

# %%
[cbs(pos, week) for pos in positions for week in weeks]
# Out:
# writing:  fftoday_QB_week1.csv
# writing:  fftoday_QB_week2.csv
# writing:  fftoday_QB_week3.csv
# writing:  fftoday_QB_week4.csv
# writing:  fftoday_QB_week5.csv
# writing:  fftoday_QB_week6.csv
# writing:  fftoday_QB_week7.csv
# writing:  fftoday_QB_week8.csv
# writing:  fftoday_QB_week9.csv
# writing:  fftoday_QB_week10.csv
# writing:  fftoday_QB_week11.csv
# writing:  fftoday_QB_week12.csv
# writing:  fftoday_QB_week13.csv
# writing:  fftoday_QB_week14.csv
# writing:  fftoday_QB_week15.csv
# writing:  fftoday_QB_week16.csv
# writing:  fftoday_QB_week17.csv
# Failed: QB 18
# Failed: QB 19
# Failed: QB 20
# writing:  fftoday_QB_week21.csv
# writing:  fftoday_RB_week1.csv
# writing:  fftoday_RB_week2.csv
# writing:  fftoday_RB_week3.csv
# writing:  fftoday_RB_week4.csv
# writing:  fftoday_RB_week5.csv
# writing:  fftoday_RB_week6.csv
# writing:  fftoday_RB_week7.csv
# writing:  fftoday_RB_week8.csv
# writing:  fftoday_RB_week9.csv
# writing:  fftoday_RB_week10.csv
# writing:  fftoday_RB_week11.csv
# writing:  fftoday_RB_week12.csv
# writing:  fftoday_RB_week13.csv
# writing:  fftoday_RB_week14.csv
# writing:  fftoday_RB_week15.csv
# writing:  fftoday_RB_week16.csv
# writing:  fftoday_RB_week17.csv
# Failed: RB 18
# Failed: RB 19
# Failed: RB 20
# writing:  fftoday_RB_week21.csv
# writing:  fftoday_WR_week1.csv
# writing:  fftoday_WR_week2.csv
# writing:  fftoday_WR_week3.csv
# writing:  fftoday_WR_week4.csv
# writing:  fftoday_WR_week5.csv
# writing:  fftoday_WR_week6.csv
# writing:  fftoday_WR_week7.csv
# writing:  fftoday_WR_week8.csv
# writing:  fftoday_WR_week9.csv
# writing:  fftoday_WR_week10.csv
# writing:  fftoday_WR_week11.csv
# writing:  fftoday_WR_week12.csv
# writing:  fftoday_WR_week13.csv
# writing:  fftoday_WR_week14.csv
# writing:  fftoday_WR_week15.csv
# writing:  fftoday_WR_week16.csv
# writing:  fftoday_WR_week17.csv
# Failed: WR 18
# Failed: WR 19
# Failed: WR 20
# writing:  fftoday_WR_week21.csv
# writing:  fftoday_TE_week1.csv
# writing:  fftoday_TE_week2.csv
# writing:  fftoday_TE_week3.csv
# writing:  fftoday_TE_week4.csv
# writing:  fftoday_TE_week5.csv
# writing:  fftoday_TE_week6.csv
# writing:  fftoday_TE_week7.csv
# writing:  fftoday_TE_week8.csv
# writing:  fftoday_TE_week9.csv
# writing:  fftoday_TE_week10.csv
# writing:  fftoday_TE_week11.csv
# writing:  fftoday_TE_week12.csv
# writing:  fftoday_TE_week13.csv
# writing:  fftoday_TE_week14.csv
# writing:  fftoday_TE_week15.csv
# writing:  fftoday_TE_week16.csv
# writing:  fftoday_TE_week17.csv
# Failed: TE 18
# Failed: TE 19
# Failed: TE 20
# writing:  fftoday_TE_week21.csv
# writing:  fftoday_K_week1.csv
# writing:  fftoday_K_week2.csv
# writing:  fftoday_K_week3.csv
# writing:  fftoday_K_week4.csv
# writing:  fftoday_K_week5.csv
# writing:  fftoday_K_week6.csv
# writing:  fftoday_K_week7.csv
# writing:  fftoday_K_week8.csv
# writing:  fftoday_K_week9.csv
# writing:  fftoday_K_week10.csv
# writing:  fftoday_K_week11.csv
# writing:  fftoday_K_week12.csv
# writing:  fftoday_K_week13.csv
# writing:  fftoday_K_week14.csv
# writing:  fftoday_K_week15.csv
# writing:  fftoday_K_week16.csv
# writing:  fftoday_K_week17.csv
# Failed: K 18
# Failed: K 19
# Failed: K 20
# writing:  fftoday_K_week21.csv
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
os.chdir('..')
