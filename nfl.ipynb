# %%
from bs4 import BeautifulSoup
import requests
import csv
import os

# %%
positions = {
    'QB': 1,
    'RB': 2,
    'WR': 3,
    'TE': 4,
    'K': 7,
    'DEF': 8
}
weeks = range(1, 22)

# %%
def cbs(pos, week):
    url = 'http://fantasy.nfl.com/research/projections?position={pos}&sort=projectedPts&statCategory=projectedStats&statSeason=2017&statType=weekProjectedStats&statWeek={week}'.format(pos=positions[pos], week=week)
    try:
        contents = requests.get(url).content
        soup = BeautifulSoup(contents, "html.parser")
        table = soup.find('table')
        header = [td.text.rstrip().replace(u'\xa0', u'') for td in table.find('thead').find_all('tr')[1].find_all('th')]
        data = [[td.text.rstrip().replace(u'\xa0', u'') for td in row.find_all('td')] for row in table.find('tbody').find_all('tr')]
    except IndexError:
        print("Failed: " + pos + " " + str(week))
        return
    filename = 'nfl_{pos}_week{week}.csv'.format(pos=pos, week=week)
    with open(filename, 'w') as f:
        print('writing: ', filename)
        writer = csv.writer(f)
        try:
            writer.writerow(header)
            writer.writerows(data)
        except UnicodeEncodeError:
            print("Failed: " + pos + " " + str(week))
            print(header)
            print(data)
            return

# %%
os.chdir('nfl')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-57-1e49f8148b22> in <module>()
# ----> 1 os.chdir('nfl')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nfl'

# %%
[cbs(pos, week) for pos in positions for week in weeks]
# Out:
# writing:  nfl_QB_week1.csv
# writing:  nfl_QB_week2.csv
# writing:  nfl_QB_week3.csv
# writing:  nfl_QB_week4.csv
# writing:  nfl_QB_week5.csv
# writing:  nfl_QB_week6.csv
# writing:  nfl_QB_week7.csv
# writing:  nfl_QB_week8.csv
# writing:  nfl_QB_week9.csv
# writing:  nfl_QB_week10.csv
# writing:  nfl_QB_week11.csv
# writing:  nfl_QB_week12.csv
# writing:  nfl_QB_week13.csv
# writing:  nfl_QB_week14.csv
# writing:  nfl_QB_week15.csv
# writing:  nfl_QB_week16.csv
# writing:  nfl_QB_week17.csv
# writing:  nfl_QB_week18.csv
# writing:  nfl_QB_week19.csv
# writing:  nfl_QB_week20.csv
# writing:  nfl_QB_week21.csv
# writing:  nfl_RB_week1.csv
# writing:  nfl_RB_week2.csv
# writing:  nfl_RB_week3.csv
# writing:  nfl_RB_week4.csv
# writing:  nfl_RB_week5.csv
# writing:  nfl_RB_week6.csv
# writing:  nfl_RB_week7.csv
# writing:  nfl_RB_week8.csv
# writing:  nfl_RB_week9.csv
# writing:  nfl_RB_week10.csv
# writing:  nfl_RB_week11.csv
# writing:  nfl_RB_week12.csv
# writing:  nfl_RB_week13.csv
# writing:  nfl_RB_week14.csv
# writing:  nfl_RB_week15.csv
# writing:  nfl_RB_week16.csv
# writing:  nfl_RB_week17.csv
# writing:  nfl_RB_week18.csv
# writing:  nfl_RB_week19.csv
# writing:  nfl_RB_week20.csv
# writing:  nfl_RB_week21.csv
# writing:  nfl_WR_week1.csv
# writing:  nfl_WR_week2.csv
# writing:  nfl_WR_week3.csv
# writing:  nfl_WR_week4.csv
# writing:  nfl_WR_week5.csv
# writing:  nfl_WR_week6.csv
# writing:  nfl_WR_week7.csv
# writing:  nfl_WR_week8.csv
# writing:  nfl_WR_week9.csv
# writing:  nfl_WR_week10.csv
# writing:  nfl_WR_week11.csv
# writing:  nfl_WR_week12.csv
# writing:  nfl_WR_week13.csv
# writing:  nfl_WR_week14.csv
# writing:  nfl_WR_week15.csv
# writing:  nfl_WR_week16.csv
# writing:  nfl_WR_week17.csv
# writing:  nfl_WR_week18.csv
# writing:  nfl_WR_week19.csv
# writing:  nfl_WR_week20.csv
# writing:  nfl_WR_week21.csv
# writing:  nfl_TE_week1.csv
# writing:  nfl_TE_week2.csv
# writing:  nfl_TE_week3.csv
# writing:  nfl_TE_week4.csv
# writing:  nfl_TE_week5.csv
# writing:  nfl_TE_week6.csv
# writing:  nfl_TE_week7.csv
# writing:  nfl_TE_week8.csv
# writing:  nfl_TE_week9.csv
# writing:  nfl_TE_week10.csv
# writing:  nfl_TE_week11.csv
# writing:  nfl_TE_week12.csv
# writing:  nfl_TE_week13.csv
# writing:  nfl_TE_week14.csv
# writing:  nfl_TE_week15.csv
# writing:  nfl_TE_week16.csv
# writing:  nfl_TE_week17.csv
# writing:  nfl_TE_week18.csv
# writing:  nfl_TE_week19.csv
# writing:  nfl_TE_week20.csv
# writing:  nfl_TE_week21.csv
# writing:  nfl_K_week1.csv
# writing:  nfl_K_week2.csv
# writing:  nfl_K_week3.csv
# writing:  nfl_K_week4.csv
# writing:  nfl_K_week5.csv
# writing:  nfl_K_week6.csv
# writing:  nfl_K_week7.csv
# writing:  nfl_K_week8.csv
# writing:  nfl_K_week9.csv
# writing:  nfl_K_week10.csv
# writing:  nfl_K_week11.csv
# writing:  nfl_K_week12.csv
# writing:  nfl_K_week13.csv
# writing:  nfl_K_week14.csv
# writing:  nfl_K_week15.csv
# writing:  nfl_K_week16.csv
# writing:  nfl_K_week17.csv
# writing:  nfl_K_week18.csv
# writing:  nfl_K_week19.csv
# writing:  nfl_K_week20.csv
# writing:  nfl_K_week21.csv
# writing:  nfl_DEF_week1.csv
# writing:  nfl_DEF_week2.csv
# writing:  nfl_DEF_week3.csv
# writing:  nfl_DEF_week4.csv
# writing:  nfl_DEF_week5.csv
# writing:  nfl_DEF_week6.csv
# writing:  nfl_DEF_week7.csv
# writing:  nfl_DEF_week8.csv
# writing:  nfl_DEF_week9.csv
# writing:  nfl_DEF_week10.csv
# writing:  nfl_DEF_week11.csv
# writing:  nfl_DEF_week12.csv
# writing:  nfl_DEF_week13.csv
# writing:  nfl_DEF_week14.csv
# writing:  nfl_DEF_week15.csv
# writing:  nfl_DEF_week16.csv
# writing:  nfl_DEF_week17.csv
# writing:  nfl_DEF_week18.csv
# writing:  nfl_DEF_week19.csv
# writing:  nfl_DEF_week20.csv
# writing:  nfl_DEF_week21.csv
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
os.chdir('..')
