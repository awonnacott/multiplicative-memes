# %%
from bs4 import BeautifulSoup
import requests
import csv
import os

# %%
positions = [
    'QB',
    'RB',
    'WR',
    'TE',
    'K',
    'DST',
]
weeks = range(1, 22)

# %%
def cbs(pos, week):
    url = 'https://www.cbssports.com/fantasy/football/stats/sortable/points/{pos}/standard/projections/2017/{week}?&print_rows=9999'.format(pos=pos, week=week)
    try:
        contents = requests.get(url).content
        soup = BeautifulSoup(contents, "html.parser")
        rows = soup.find('table').find_all('tr')
        header = [td.text.split(',')[0] for td in rows[2]]
        data = [[td.text.split(',')[0] for td in row] for row in rows[3:-1]]
    except IndexError:
        print("Failed: " + pos + " " + str(week))
        return
    filename = 'cbs_{pos}_week{week}.csv'.format(pos=pos, week=week)
    with open(filename, 'w') as f:
        print('writing: ', filename)
        writer = csv.writer(f)
        try:
            writer.writerow(header)
            writer.writerows(data)
        except UnicodeEncodeError:
            print("Failed: " + pos + " " + str(week))
            print(header)
            print(data)
            return

# %%
os.chdir('cbs')

# %%
[cbs(pos, week) for pos in positions for week in weeks]
# Out:
# writing:  cbs_QB_week1.csv
# writing:  cbs_QB_week2.csv
# writing:  cbs_QB_week3.csv
# writing:  cbs_QB_week4.csv
# writing:  cbs_QB_week5.csv
# writing:  cbs_QB_week6.csv
# writing:  cbs_QB_week7.csv
# writing:  cbs_QB_week8.csv
# writing:  cbs_QB_week9.csv
# writing:  cbs_QB_week10.csv
# writing:  cbs_QB_week11.csv
# writing:  cbs_QB_week12.csv
# writing:  cbs_QB_week13.csv
# writing:  cbs_QB_week14.csv
# writing:  cbs_QB_week15.csv
# writing:  cbs_QB_week16.csv
# writing:  cbs_QB_week17.csv
# writing:  cbs_QB_week18.csv
# writing:  cbs_QB_week19.csv
# writing:  cbs_QB_week20.csv
# writing:  cbs_QB_week21.csv
# writing:  cbs_RB_week1.csv
# writing:  cbs_RB_week2.csv
# writing:  cbs_RB_week3.csv
# writing:  cbs_RB_week4.csv
# writing:  cbs_RB_week5.csv
# writing:  cbs_RB_week6.csv
# writing:  cbs_RB_week7.csv
# writing:  cbs_RB_week8.csv
# writing:  cbs_RB_week9.csv
# writing:  cbs_RB_week10.csv
# writing:  cbs_RB_week11.csv
# writing:  cbs_RB_week12.csv
# writing:  cbs_RB_week13.csv
# writing:  cbs_RB_week14.csv
# writing:  cbs_RB_week15.csv
# writing:  cbs_RB_week16.csv
# writing:  cbs_RB_week17.csv
# writing:  cbs_RB_week18.csv
# writing:  cbs_RB_week19.csv
# writing:  cbs_RB_week20.csv
# writing:  cbs_RB_week21.csv
# writing:  cbs_WR_week1.csv
# writing:  cbs_WR_week2.csv
# writing:  cbs_WR_week3.csv
# writing:  cbs_WR_week4.csv
# writing:  cbs_WR_week5.csv
# writing:  cbs_WR_week6.csv
# writing:  cbs_WR_week7.csv
# writing:  cbs_WR_week8.csv
# writing:  cbs_WR_week9.csv
# writing:  cbs_WR_week10.csv
# writing:  cbs_WR_week11.csv
# writing:  cbs_WR_week12.csv
# writing:  cbs_WR_week13.csv
# writing:  cbs_WR_week14.csv
# writing:  cbs_WR_week15.csv
# writing:  cbs_WR_week16.csv
# writing:  cbs_WR_week17.csv
# writing:  cbs_WR_week18.csv
# writing:  cbs_WR_week19.csv
# writing:  cbs_WR_week20.csv
# writing:  cbs_WR_week21.csv
# writing:  cbs_TE_week1.csv
# writing:  cbs_TE_week2.csv
# writing:  cbs_TE_week3.csv
# writing:  cbs_TE_week4.csv
# writing:  cbs_TE_week5.csv
# writing:  cbs_TE_week6.csv
# writing:  cbs_TE_week7.csv
# writing:  cbs_TE_week8.csv
# writing:  cbs_TE_week9.csv
# writing:  cbs_TE_week10.csv
# writing:  cbs_TE_week11.csv
# writing:  cbs_TE_week12.csv
# writing:  cbs_TE_week13.csv
# writing:  cbs_TE_week14.csv
# writing:  cbs_TE_week15.csv
# writing:  cbs_TE_week16.csv
# writing:  cbs_TE_week17.csv
# writing:  cbs_TE_week18.csv
# writing:  cbs_TE_week19.csv
# writing:  cbs_TE_week20.csv
# writing:  cbs_TE_week21.csv
# writing:  cbs_K_week1.csv
# writing:  cbs_K_week2.csv
# writing:  cbs_K_week3.csv
# writing:  cbs_K_week4.csv
# writing:  cbs_K_week5.csv
# writing:  cbs_K_week6.csv
# writing:  cbs_K_week7.csv
# writing:  cbs_K_week8.csv
# writing:  cbs_K_week9.csv
# writing:  cbs_K_week10.csv
# writing:  cbs_K_week11.csv
# writing:  cbs_K_week12.csv
# writing:  cbs_K_week13.csv
# writing:  cbs_K_week14.csv
# writing:  cbs_K_week15.csv
# writing:  cbs_K_week16.csv
# writing:  cbs_K_week17.csv
# writing:  cbs_K_week18.csv
# Failed: K 19
# Failed: K 20
# writing:  cbs_K_week21.csv
# writing:  cbs_DST_week1.csv
# writing:  cbs_DST_week2.csv
# writing:  cbs_DST_week3.csv
# writing:  cbs_DST_week4.csv
# writing:  cbs_DST_week5.csv
# writing:  cbs_DST_week6.csv
# writing:  cbs_DST_week7.csv
# writing:  cbs_DST_week8.csv
# writing:  cbs_DST_week9.csv
# writing:  cbs_DST_week10.csv
# writing:  cbs_DST_week11.csv
# writing:  cbs_DST_week12.csv
# writing:  cbs_DST_week13.csv
# writing:  cbs_DST_week14.csv
# writing:  cbs_DST_week15.csv
# writing:  cbs_DST_week16.csv
# writing:  cbs_DST_week17.csv
# writing:  cbs_DST_week18.csv
# Failed: DST 19
# Failed: DST 20
# writing:  cbs_DST_week21.csv
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
os.chdir('..')
